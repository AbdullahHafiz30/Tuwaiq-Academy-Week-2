# %% [markdown]
# ### **Hi , we will learn how to find a Correlation in our datasets.**
#
# ### **Let's get started: **

# %% [markdown]
# ### **Import our Libraries**

# %%
import pandas as pd # To read and analysis our data
import seaborn as sns # to see correlation in the dataset using Heat map
import matplotlib.pyplot as plt # to Visualize our dataset

# %% [markdown]
# ### **Read data set and display our dataset**

# %%
df = pd.read_csv("C:\\Users\\abo_O\\OneDrive\\سطح المكتب\\Tuwaiq Academy\\Tuwaiq-Academy-Week-2\\Week-2-LAB-1\\Dataset\\Expanded_data_with_more_features.csv")
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0           none             married     regularly          yes         3.0
# 1            NaN             married     sometimes          yes         0.0
# 2           none              single     sometimes          yes         4.0
# 3           none             married         never           no         1.0
# 4           none             married     sometimes          yes         0.0
# ...          ...                 ...           ...          ...         ...
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 3.5+ MB

# %% [markdown]
# ### **Explanation of the Dataset**

# %% [markdown]
# so we have 14 Columns , we can see that this is a Dataset for students preformence.
#
# `Gender` : Male or Female.
#
# `EthnicGroup` : which group this student belongs to.
#
# `ParentEduc` : Education of parents students.
#
# `LunchType` : Launch type of the students.
#
# `TestPrep` : do the student do a test prepreation before the exam or not.
#
# `ParentMaritalStatus` : is the parents married or devorsed.
#
# `PracticeSport` : dose the student practies support or not.
#
# `IsFirstChild` : is this student the first child [Y/N].
#
# `NrSiblings` : Number of sbilings.
#
# `TransportMeans ` : How do the students go to school.
#
#
# `WklyStudyHours` : Number of Hours they studes Weekly.
#
# `MathScore` : Degree in math test.
#
# `ReadingScore`: Degree in English Reading test.
#
# `WritingScore` : Degree in English Writing test.

# %% [markdown]
# ## **Let's do some EDA :**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %% [markdown]
# ### **we have so many nulls value ...**
#
# ### **let's handle them :**

# %%
df["EthnicGroup"].fillna("Other" , inplace =True)
# if they don't belong to any existing group that's mean they belong to 'Other' Gropups
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\1024818168.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["EthnicGroup"].fillna("Other" , inplace =True)

# %%
df["ParentEduc"].fillna("Other" , inplace =True)
# if they don't have any existing Education that's mean they belong to 'Other'parent Education
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\1553366536.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ParentEduc"].fillna("Other" , inplace =True)

# %%
df["TestPrep"].mode()
#check the mode if it's possible to fill it with mode.
# Out:
# 0    none
# Name: TestPrep, dtype: object

# %%
df["TestPrep"].fillna("Unkown" , inplace =True)
#Fill the null with 'Unkown' 'cause we don't know if they did the test prep or no.
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\50789524.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["TestPrep"].fillna("Unkown" , inplace =True)

# %%
df['NrSiblings'] = df['NrSiblings'].astype(pd.Int64Dtype())
#change type of Number of Siblings to int so we can see the max , min , mean and count
#let's describe df

# %%
df.describe()
# Out:
#          Unnamed: 0  NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000     29069.0  30641.000000  30641.000000  30641.000000
# mean     499.556607    2.145894     66.558402     69.377533     68.418622
# std      288.747894    1.458242     15.361616     14.758952     15.443525
# min        0.000000         0.0      0.000000     10.000000      4.000000
# 25%      249.000000         1.0     56.000000     59.000000     58.000000
# 50%      500.000000         2.0     67.000000     70.000000     69.000000
# 75%      750.000000         3.0     78.000000     80.000000     79.000000
# max      999.000000         7.0    100.000000    100.000000    100.000000

# %%
#we can see that the number of Siblings mean is 2 so :
df['NrSiblings'].fillna(2, inplace=True)
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\96176979.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NrSiblings'].fillna(2, inplace=True)

# %%
df["WklyStudyHours"].mode()
#check the mode
# Out:
# 0    5 - 10
# Name: WklyStudyHours, dtype: object

# %%
df['WklyStudyHours'].fillna(5 - 10, inplace=True)
#fill the null '5 - 10'
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\3635287184.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WklyStudyHours'].fillna(5 - 10, inplace=True)

# %%
df["ParentMaritalStatus"].mode()
#check the mode
# Out:
# 0    married
# Name: ParentMaritalStatus, dtype: object

# %%
df['ParentMaritalStatus'].fillna("married", inplace=True)
#fill the null 'married'
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\2081647408.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ParentMaritalStatus'].fillna("married", inplace=True)

# %%
df['IsFirstChild'].fillna("Unkown", inplace=True)
# we don't know if this student if he/she the 1st child or not.
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\1050197603.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['IsFirstChild'].fillna("Unkown", inplace=True)

# %%
df["PracticeSport"].mode()
#check the mode
# Out:
# 0    sometimes
# Name: PracticeSport, dtype: object

# %%
df['PracticeSport'].fillna("sometimes", inplace=True)
# fill with the mode
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\3733204583.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PracticeSport'].fillna("sometimes", inplace=True)

# %%
df["TransportMeans"].mode()
#check the mode
# Out:
# 0    school_bus
# Name: TransportMeans, dtype: object

# %%
df['TransportMeans'].fillna("school_bus", inplace=True)
# fill with the mode
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\473635084.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TransportMeans'].fillna("school_bus", inplace=True)

# %%
# now we check if the dataset still have nulls value or no
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Gender                 0
# EthnicGroup            0
# ParentEduc             0
# LunchType              0
# TestPrep               0
# ParentMaritalStatus    0
# PracticeSport          0
# IsFirstChild           0
# NrSiblings             0
# TransportMeans         0
# WklyStudyHours         0
# MathScore              0
# ReadingScore           0
# WritingScore           0
# dtype: int64

# %% [markdown]
# ### **That's great , now we can findout what is the Correlations?**
#
# ![WhatsApp Image 2024-07-25 at 15.17.58_f552ec4c.jpg](data:image/jpeg;base64,...)
#
# `Correlations` : is a statistical measure that expresses the extent to which two variables are linearly related.
#
#
# We can find Correlations from the Features (Columns) in this dataset using heat map from seaborne lib. Let's see how it works:

# %% [markdown]
# ### Do you think the parent Education might effect in the students score?
# # Let's see :)

# %%
# create a new df we can call it df1 to make a groupby bettwen ParentEduc and the mean of the score of each test like this :

df1=df.groupby("ParentEduc").agg({"MathScore":'mean',"ReadingScore":'mean',"WritingScore":'mean'} , inplace = True)
print(df1)
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# Other               66.645528     69.225474     68.295935
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
# now we can do the heatmap :

sns.heatmap(df1 , annot= True)
plt.title("how parent's Education effect on student's score")
plt.show()

# %% [markdown]
# **Now we can see the correlations bettwen the parents who have master degree the students Scores.**
#
# **So we can findout : That the student's who have High scores there parents have master dgree.**

# %% [markdown]
# #**Now it's your turn to find out more correlations the same way we did before**
# ###**Fill the '-----' with your thoughts.**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
df2=df.groupby("EthnicGroup").agg({"WritingScore":'mean',"ReadingScore":'mean',"MathScore":'mean'} , inplace = True)
print(df2)
# Out:
#              WritingScore  ReadingScore  MathScore
# EthnicGroup
# Other           67.900543     68.915761  66.185870
# group A         65.251915     66.787742  62.991888
# group B         65.895125     67.320460  63.490216
# group C         66.999240     68.438233  64.695723
# group D         70.890844     70.382247  67.666400
# group E         72.677060     74.251423  75.298936

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df2 , annot= True)
plt.title("how Ethnicity can affect scores")
plt.show()

# %% [markdown]
# ### here we can see that group E has higher scores than most groups

# %% [markdown]
# #**Now you can start working in finding out the Correlations with your own :**

# %% [markdown]
# # let's start over by reading the dataset

# %%
df = pd.read_csv("C:\\Users\\abo_O\\OneDrive\\سطح المكتب\\Tuwaiq Academy\\Tuwaiq-Academy-Week-2\\Week-2-LAB-1\\Dataset\\Expanded_data_with_more_features.csv")
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0           none             married     regularly          yes         3.0
# 1            NaN             married     sometimes          yes         0.0
# 2           none              single     sometimes          yes         4.0
# 3           none             married         never           no         1.0
# 4           none             married     sometimes          yes         0.0
# ...          ...                 ...           ...          ...         ...
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 15 columns]

# %% [markdown]
# ### column unnamed: 0 looks useless so let's drop it

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0      female         NaN   bachelor's degree      standard       none
# 1      female     group C        some college      standard        NaN
# 2      female     group B     master's degree      standard       none
# 3        male     group A  associate's degree  free/reduced       none
# 4        male     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30638  female         NaN         high school  free/reduced  completed
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0                 married     regularly          yes         3.0
# 1                 married     sometimes          yes         0.0
# 2                  single     sometimes          yes         4.0
# 3                 married         never           no         1.0
# 4                 married     sometimes          yes         0.0
# ...                   ...           ...          ...         ...
# 30636              single     sometimes           no         2.0
# 30637              single     regularly           no         1.0
# 30638             married     sometimes           no         1.0
# 30639             married     regularly           no         3.0
# 30640             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %% [markdown]
# ### now let's check for missing and duplactes values

# %%
df.isnull().sum()
# Out:
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### we have a lot of missing vales and no duplcates let's handle them
# ## first let's handle the missing values in the EthnicGroup

# %%
df['EthnicGroup'].fillna(df['EthnicGroup'].mode()[0], inplace=True)
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\791370263.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['EthnicGroup'].fillna(df['EthnicGroup'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                    0
# EthnicGroup               0
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df.dtypes
# Out:
# Gender                  object
# EthnicGroup             object
# ParentEduc              object
# LunchType               object
# TestPrep                object
# ParentMaritalStatus     object
# PracticeSport           object
# IsFirstChild            object
# NrSiblings             float64
# TransportMeans          object
# WklyStudyHours          object
# MathScore                int64
# ReadingScore             int64
# WritingScore             int64
# dtype: object

# %% [markdown]
# ### let's seprate the objects columns from the dataset to handle the missing values on them sepertally

# %%
odf = df.select_dtypes('object')
odf.dtypes
# Out:
# Gender                 object
# EthnicGroup            object
# ParentEduc             object
# LunchType              object
# TestPrep               object
# ParentMaritalStatus    object
# PracticeSport          object
# IsFirstChild           object
# TransportMeans         object
# WklyStudyHours         object
# dtype: object

# %%
for col in odf:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\3464174244.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                    0
# EthnicGroup               0
# ParentEduc                0
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus       0
# PracticeSport             0
# IsFirstChild              0
# NrSiblings             1572
# TransportMeans            0
# WklyStudyHours            0
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %% [markdown]
# ### the last column with missing values is a flout type let's see what we should do with it

# %%
df['NrSiblings'].describe()
# Out:
# count    29069.000000
# mean         2.145894
# std          1.458242
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          7.000000
# Name: NrSiblings, dtype: float64

# %% [markdown]
# ### the mean of the column is 2.1 let's round to 2 and fill the missing values

# %%
df['NrSiblings'].fillna(2, inplace=True)
# Out:
# C:\Users\abo_O\AppData\Local\Temp\ipykernel_5376\1333806987.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NrSiblings'].fillna(2, inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                 0
# EthnicGroup            0
# ParentEduc             0
# LunchType              0
# TestPrep               0
# ParentMaritalStatus    0
# PracticeSport          0
# IsFirstChild           0
# NrSiblings             0
# TransportMeans         0
# WklyStudyHours         0
# MathScore              0
# ReadingScore           0
# WritingScore           0
# dtype: int64

# %% [markdown]
# ### now that we handled all missing values let's check the data types

# %%
df.dtypes
# Out:
# Gender                  object
# EthnicGroup             object
# ParentEduc              object
# LunchType               object
# TestPrep                object
# ParentMaritalStatus     object
# PracticeSport           object
# IsFirstChild            object
# NrSiblings             float64
# TransportMeans          object
# WklyStudyHours          object
# MathScore                int64
# ReadingScore             int64
# WritingScore             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               30641 non-null  object
#  1   EthnicGroup          30641 non-null  object
#  2   ParentEduc           30641 non-null  object
#  3   LunchType            30641 non-null  object
#  4   TestPrep             30641 non-null  object
#  5   ParentMaritalStatus  30641 non-null  object
#  6   PracticeSport        30641 non-null  object
#  7   IsFirstChild         30641 non-null  object
#  8   NrSiblings           30641 non-null  float64
#  9   TransportMeans       30641 non-null  object
#  10  WklyStudyHours       30641 non-null  object
#  11  MathScore            30641 non-null  int64
#  12  ReadingScore         30641 non-null  int64
#  13  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 3.3+ MB

# %%
df
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0      female     group C   bachelor's degree      standard       none
# 1      female     group C        some college      standard       none
# 2      female     group B     master's degree      standard       none
# 3        male     group A  associate's degree  free/reduced       none
# 4        male     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30638  female     group C         high school  free/reduced  completed
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0                 married     regularly          yes         3.0
# 1                 married     sometimes          yes         0.0
# 2                  single     sometimes          yes         4.0
# 3                 married         never           no         1.0
# 4                 married     sometimes          yes         0.0
# ...                   ...           ...          ...         ...
# 30636              single     sometimes           no         2.0
# 30637              single     regularly           no         1.0
# 30638             married     sometimes           no         1.0
# 30639             married     regularly           no         3.0
# 30640             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1         school_bus         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3         school_bus         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 14 columns]

# %%
df['IsFirstChild'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# ### the number of sibling shouldn't be a flout and the IsFirstChild could be encoded to true & false

# %%
df['NrSiblings'] = df['NrSiblings'].astype('int64')

# %%
df.dtypes
# Out:
# Gender                 object
# EthnicGroup            object
# ParentEduc             object
# LunchType              object
# TestPrep               object
# ParentMaritalStatus    object
# PracticeSport          object
# IsFirstChild           object
# NrSiblings              int64
# TransportMeans         object
# WklyStudyHours         object
# MathScore               int64
# ReadingScore            int64
# WritingScore            int64
# dtype: object

# %%
df['NrSiblings']
# Out:
# 0        3
# 1        0
# 2        4
# 3        1
# 4        0
#         ..
# 30636    2
# 30637    1
# 30638    1
# 30639    3
# 30640    1
# Name: NrSiblings, Length: 30641, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

Label_encoder = LabelEncoder()

df['FirstChild_Encoded'] = Label_encoder.fit_transform(df['IsFirstChild'])

# %%
df
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0      female     group C   bachelor's degree      standard       none
# 1      female     group C        some college      standard       none
# 2      female     group B     master's degree      standard       none
# 3        male     group A  associate's degree  free/reduced       none
# 4        male     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30638  female     group C         high school  free/reduced  completed
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0                 married     regularly          yes           3
# 1                 married     sometimes          yes           0
# 2                  single     sometimes          yes           4
# 3                 married         never           no           1
# 4                 married     sometimes          yes           0
# ...                   ...           ...          ...         ...
# 30636              single     sometimes           no           2
# 30637              single     regularly           no           1
# 30638             married     sometimes           no           1
# 30639             married     regularly           no           3
# 30640             married         never           no           1
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore  \
# 0         school_bus            < 5         71            71            74
# 1         school_bus         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3         school_bus         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
#        FirstChild_Encoded
# 0                       1
# 1                       1
# 2                       1
# 3                       0
# 4                       1
# ...                   ...
# 30636                   0
# 30637                   0
# 30638                   0
# 30639                   0
# 30640                   0
#
# [30641 rows x 15 columns]

# %% [markdown]
# ### now let's see the corrlation matrix by groupong and aggrigating

# %%
df3 = df.groupby('FirstChild_Encoded').agg({"WritingScore":'mean',"ReadingScore":'mean',"MathScore":'mean'})
print(df3)
# Out:
#                     WritingScore  ReadingScore  MathScore
# FirstChild_Encoded
# 0                      68.210887     69.132614  66.246832
# 1                      68.529371     69.508106  66.724507

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df3 , annot= True)
plt.title("does being the first child affect scores")
plt.show()

# %% [markdown]
# ### let's see if having siblings effect scores

# %%
df4 = df.groupby('NrSiblings').agg({"WritingScore":'mean',"ReadingScore":'mean',"MathScore":'mean'})
print(df4)
# Out:
#             WritingScore  ReadingScore  MathScore
# NrSiblings
# 0              68.746515     69.547812  66.819449
# 1              68.245345     69.259097  66.473896
# 2              68.441402     69.425257  66.512557
# 3              68.650498     69.488159  66.719092
# 4              68.073444     69.144169  66.245495
# 5              68.282576     69.453788  66.630303
# 6              67.860927     68.801325  65.917219
# 7              68.986254     69.828179  67.615120

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df4 , annot= True)
plt.title("does having siblings affect scores")
plt.show()

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore', 'FirstChild_Encoded'],
#       dtype='object')

# %% [markdown]
# ### let's see if parents marital status effect scores

# %%
df3 = df.groupby('ParentMaritalStatus').agg({"WritingScore":'mean',"ReadingScore":'mean',"MathScore":'mean'})
print(df3)
# Out:
#                      WritingScore  ReadingScore  MathScore
# ParentMaritalStatus
# divorced                68.799146     69.655011  66.691197
# married                 68.406177     69.379561  66.650161
# single                  68.174440     69.157250  66.165704
# widowed                 68.563452     69.651438  67.368866

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df3 , annot= True)
plt.title("does Parent Marital Status affect scores")
plt.show()

# %% [markdown]
# # we see here that parent marital status and having sinlings and being the first chiled does not affect the scores of the chiled which is good
